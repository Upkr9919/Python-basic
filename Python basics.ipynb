# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
print(a)
# Out:
# 10

# %%
a
# Out:
# 10

# %%
print()

# %%
b='errr'

# %%
print(a,"werrr",sep='%')
# Out:
# 10%werrr

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(b))
# Out:
# <class 'str'>

# %%
x=1000

# %%
y =1000

# %%
x=50
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 x.id
#
# AttributeError: 'int' object has no attribute 'id'

# %%
y=50

# %%
id(y)
# Out:
# 140716694319064

# %%
id(x)
# Out:
# 2219845155056

# %%
x=7

# %%
id(x)
# Out:
# 140716694317688

# %%
x=20

# %%
id(x)
# Out:
# 140716694318104

# %%
y=20

# %%
id(y)
# Out:
# 140716694318104

# %%
m=1000

# %%
id(m)
# Out:
# 2219790118448

# %%
n=1000

# %%
id(n)
# Out:
# 2219814039472

# %%
c = 4+5j

# %%
complex(4,5)
# Out:
# (4+5j)

# %%
print(c)
# Out:
# (4+5j)

# %%
c.real
# Out:
# 4.0

# %%
c.imag
# Out:
# 5.0

# %%
c
# Out:
# (4+5j)

# %%
a= 4.9999999

# %%
type(a)
# Out:
# float

# %%
s = 'smashers gamee sudos'

# %%
print(s[::])
# Out:
# smashers gamee sudos

# %%
python -V
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 python -V
#
# NameError: name 'python' is not defined

# %%
python -version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 python -version
#
# NameError: name 'python' is not defined

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 python --version
#
# NameError: name 'python' is not defined

# %%
String = "Semo"

# %%
King = "Demon"

# %%
print(String+King)
# Out:
# SSSSDemon

# %%
print(King*10)
# Out:
# DemonDemonDemonDemonDemonDemonDemonDemonDemonDemon

# %%
print(String > King)
# Out:
# True

# %%
print('c'>'Abc')
# Out:
# True

# %%
name = 'SHYAM'
age = 25

# %%
print(f"My name is {name} and age is {age}")
# Out:
# My name is SHYAM and age is 25

# %%
#[start:end:step_size]

# %%
str1 = 'Hello World'

# %%
str1[2:8]
# Out:
# 'llo Wo'

# %%
str1[-3::-1]
# Out:
# 'roW olleH'

# %%
#Split
spd ="My name is name and age is age"

# %%
print(spd.split())
# Out:
# ['My', 'name', 'is', 'name', 'and', 'age', 'is', 'age']

# %%
newstr="abs, bbs, sdk, gfg, fm, vb"

# %%
print(newstr.split(','))
# Out:
# ['abs', ' bbs', ' sdk', ' gfg', ' fm', ' vb']

# %%
print(spd.split(','))
# Out:
# ['My name is name and age is age']

# %%
#replace(old,new,count)

# %%
spd1="My name is name and age is age"

# %%
print(spd1.replace('name', 'Ravi',1))
# Out:
# My Ravi is name and age is age

# %%
# Python3 program to show the
# working of upper() function
text = 'geeKs For geEkS'

# upper() function to convert
# string to upper case
print("\nConverted String:")
print(text.upper())

# lower() function to convert
# string to lower case
print("\nConverted String:")
print(text.lower())

# converts the first character to 
# upper case and rest to lower case 
print("\nConverted String:")
print(text.title())

# swaps the case of all characters in the string
# upper case character to lowercase and viceversa
print("\nConverted String:")
print(text.swapcase())

# convert the first character of a string to uppercase
print("\nConverted String:")
print(text.capitalize())

# original string never changes
print("\nOriginal String")
print(text)
# Out:
# Converted String:
# GEEKS FOR GEEKS
#
# Converted String:
# geeks for geeks
#
# Converted String:
# Geeks For Geeks
#
# Converted String:
# GEEkS fOR GEeKs
#
# Converted String:
# Geeks for geeks
#
# Original String
# geeKs For geEkS

# %%
print(spd)
# Out:
# My name is name and age is age

# %%
#List
a = []
b = list()

# %%
type(a)
# Out:
# list

# %%
type(b)
# Out:
# list

# %%
a = [23, 90, 40,'ad', [20,'fg']]

# %%
print(a[4][1])
# Out:
# fg

# %%
a.append(50)

# %%
print(a)
# Out:
# [23, 90, 40, 'ad', [20, 'fg'], 50, 50]

# %%
a[-1]=70
print(a)
# Out:
# [23, 90, 40, 'ad', [20, 'fg'], 50, 70]

# %%
a.insert(3,'dh')
print(a)
# Out:
# [23, 90, 40, 'dh', 'ad', [20, 'fg'], 50, 70]

# %%
a.extend([44,'k','mu'])

# %%
print(a)
# Out:
# [23, 90, 40, 'dh', 'ad', [20, 'fg'], 50, 70, 44, 'k', 'mu']

# %%
a.append([44,'k','mu'])
print(a)
# Out:
# [23, 90, 40, 'dh', 'ad', [20, 'fg'], 50, 70, 44, 'k', 'mu', [44, 'k', 'mu']]

# %%
#remove in lst
a.remove(0)
print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[166], line 2
#       1 #remove in lst
# ----> 2 a.remove(0)
#       3 print(a)
#
# ValueError: list.remove(x): x not in list

# %%
a.insert(-90,'dhrk')
print(a)
# Out:
# ['dhrk', 23, 90, 'dh', 'ad', [20, 'fg'], 50, 70, 44, 'k', 'mu', [44, 'k', 'mu'], 'dh', 'dh', 'dhrk']

# %%
a.remove('dh')
print(a)
# Out:
# ['dhrk', 23, 90, 'ad', [20, 'fg'], 50, 70, 44, 'k', 'mu', [44, 'k', 'mu'], 'dh', 'dh', 'dhrk']

# %%
del a[7]
print(a)
# Out:
# ['dhrk', 23, 90, 'ad', [20, 'fg'], 50, 70, 'k', 'mu', [44, 'k', 'mu'], 'dh', 'dh', 'dhrk']

# %%
del a[3:9]
print(a)
# Out:
# ['dhrk', 23, 90, [44, 'k', 'mu'], 'dh', 'dh', 'dhrk']

# %%
#clear
a.clear()

# %%
a.pop()
print(a)
# Out:
# ['dhrk', 23, 90, [44, 'k', 'mu'], 'dh', 'dh']

# %%
a.pop(3)
print(a)
# Out:
# ['dhrk', 23, 90, 'dh', 'dh']

# %%
a.clear()

# %%
a.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 a.pop()
#
# IndexError: pop from empty list

# %%
#unpacking
a,b,c = [10,"shirt",3]

# %%
print(a)
print(b)
print(c)
# Out:
# 10
# shirt
# 3

# %%
a,*b,c = [10,90,"b",'c',67,89,90]
print(a)
print(b)
print(c)
# Out:
# 10
# [90, 'b', 'c', 67, 89]
# 90

# %%
#sort
lst = [23, 90, 40, 20, 50, 70, 44]
lst.sort()
print(lst)
# Out:
# [20, 23, 40, 44, 50, 70, 90]

# %%
lst = [23, 90, 40, 20, 50, 70, 44]
lst.sort(reverse = True)
print(lst)
# Out:
# [90, 70, 50, 44, 40, 23, 20]

# %%
lst = [23, 90, 40, 20, 50, 70, 44]
a = sorted(lst)
print(lst)
print(a)
# Out:
# [23, 90, 40, 20, 50, 70, 44]
# [20, 23, 40, 44, 50, 70, 90]

# %%
lst = [23, 90, 40, 20, 50, 70, 44]
a = sorted(lst,reverse=True)
print(lst)
print(a)
# Out:
# [23, 90, 40, 20, 50, 70, 44]
# [90, 70, 50, 44, 40, 23, 20]

# %%
lst = [23, 90, 44, 50, 50, 70, 44]
lst1 = list(set(lst))
print(lst1)
# Out:
# [70, 44, 50, 23, 90]

# %%
lst = [23, 90, 44, 50, 50, 70, 44]
a = list(dict.fromkeys(lst))
print(a)
# Out:
# [23, 90, 44, 50, 70]

# %%
#ASCII
#A-65 Z-90 a=97 z=112

# %%
#tuple
t = 1,
t1 = (1,)
t2 = tuple((1,2,3))

# %%
type(t1)
# Out:
# tuple

# %%
t2[2]
# Out:
# 3

# %%
a,b,c = (1,2,3)
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
a,*b = (1,2,3)
print(a)
print(b)
# Out:
# 1
# [2, 3]

# %%
age = int(input("Enter Age :"))
if age>17:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Enter Age : 23
# Eligible

# %%
def calc(num1,num2,opr) -> str:
    num1 = num1
    num2 = num2
    opr  = opr
    match opr:
       case '+': return(str(num1+num2))
       case '-': return(str(num1-num2))
       case '*': return(str(num1*num2))
       case '/': return(str(num1/num2))
       case '%': return(str(num1%num2))    
       case _  : return("No operator found")  
    return 
operator = ['+','-','*','/','%']
num1 = str(input("Enter num1 : "))
num2 = str(input("Enter num2 : "))
opr = str(input("Input your operator('+','-','*','/','%'): "))
n1 = 0
n2 = 0
c1 = 0
c2 = 0
for i in num1:
    if i == '.': 
        n1 = float(num1)
        c1 += 1 
for i in num2:
    if i == '.': 
        n2 = float(num1)
        c2 += 1
if c1 == 0:
    n1 = int(num1)
if c2 == 0:
    n2 = int(num2)

print(calc(n1,n2,opr))
# Out:
# Enter num1 :  23
# Enter num2 :  23
# Input your operator('+','-','*','/','%'):  *
# 529

# %%
#Reverse String
num = int(input("NUM :"))

def reverse(num):
   rev = 0
    
   while num > 0:
      n = num%10
      rev = rev*10+n
      num = num//10    

   print(rev)

reverse(num)
# Out:
# NUM : 34
# 8991

# %%
#prime number
def prime(num):
    count = 0
    for i in range(1,num):
        if num%i == 0:
            count += 1
    if count>1:
        print("Not prime")
    else:
        print("Prime")

prime(4)
# Out:
# Not prime

# %%
ord('A')
# Out:
# 65

# %%
#enumerate() 
lst = (10,20,30,40)
for i,v in enumerate(lst):
    print(v,i)
# Out:
# 10 0
# 20 1
# 30 2
# 40 3

# %%
#zip()
lst1 = ["APPLE", "SAMSUNG","OPPO","MOTOROLA", "VIVO"]
lst2 =  [100000,50000,35000,25000,22000]
for a,b in zip(lst1,lst2):
    print(a,b,sep=':')
# Out:
# APPLE:100000
# SAMSUNG:50000
# OPPO:35000
# MOTOROLA:25000
# VIVO:22000

# %%
def myfunc(a):
  return a

x = map(myfunc, ('apple', 'banana', 'cherry'))

print(list(x))
# Out:
# ['apple', 'banana', 'cherry']

# %%
mytuple = ("apple", "banana", "cherry")
myit = iter(mytuple)

print(next(myit))
print(next(myit))
print(next(myit))
# Out:
# apple
# banana
# cherry

# %%
class MyNumbers:
  def __iter__(self):
    self.a = 65
    return self

  def __next__(self):
    x = self.a
    self.a += 334
    return x

myclass = MyNumbers()
myiter = iter(myclass)

print(next(myiter))
print(next(myiter))
print(next(myiter))
print(next(myiter))
print(next(myiter))
# Out:
# 65
# 66
# 67
# 68
# 69

# %%
import platform

x = platform.system()
print(x)

x = dir(platform)
print(x)
# Out:
# Windows
# ...

# %%
import datetime

x = datetime.datetime.now()
print(x)
# Out:
# 2026-01-31 23:17:17.370288

# %%
try:
  x = 10
except:
  print("Something went wrong")
else:
  print("Sorry")
finally:
  print("The 'try except' is finished")
# Out:
# Sorry
# The 'try except' is finished

# %%
try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
finally:
  print("The 'try except' is finished")
# Out:
# Hello
# Nothing went wrong
# The 'try except' is finished

# %%
'''The per-unit charges in rupees are as follows: 
For the first 100 units, the user will be charged Rs. 4.5 per unit, 
for the next 100 units, the user will be charged Rs. 6 per unit, 
and for the next 100 units, the user will
be charged Rs. 10 per unit, 
After 300 units and above the user will be charged Rs. 20 per unit.
You are required to take the units of electricity consumed in a month from the user as input.
Your program must pass this test case: when the unit of electricity consumed by the user in a month is
310, the total electricity bill should be 2250.'''

unit = int(input("Enter unit consumed : "))
bill = 0

if (unit<=100):
    bill = unit*4.5
elif(unit<=200):
    bill = (100*4.5)+(unit-100)*6
elif(unit<=300):
    bill = (100*4.5) + (100*6)+(unit-200)*10
else:
    bill = (100*4.5)+(100*6)+(100*10)+(unit-300)*20

print(bill)
# Out:
# Enter unit consumed :  310
# 2250.0

# %%
#310*20
